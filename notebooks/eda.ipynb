# %%
import duckdb
import pandas as pd

db_path = "/Users/folkert/think_onward/data/eaglei_data.duckdb"

with duckdb.connect(database=db_path) as conn:
    df = conn.execute("SELECT * FROM eaglei_data WHERE customers_out IS NOT NULL LIMIT 10;").fetchdf()
    display(df)
# Out:
#   fips_code       county       state  customers_out      run_start_time
# 0     01037        Coosa     Alabama             12 2014-11-01 04:00:00
# 1     01051       Elmore     Alabama              7 2014-11-01 04:00:00
# 2     01109         Pike     Alabama              1 2014-11-01 04:00:00
# 3     01121    Talladega     Alabama             31 2014-11-01 04:00:00
# 4     04017       Navajo     Arizona              1 2014-11-01 04:00:00
# 5     05009        Boone    Arkansas              3 2014-11-01 04:00:00
# 6     05119      Pulaski    Arkansas              1 2014-11-01 04:00:00
# 7     06029         Kern  California             30 2014-11-01 04:00:00
# 8     06037  Los Angeles  California           1555 2014-11-01 04:00:00
# 9     06065    Riverside  California              2 2014-11-01 04:00:00

# %%
import pandas as pd
import duckdb

def process_state_county(conn, state, county):
    if "'" in county:
        county = county.replace("'", "''")
    query = f"""
    SELECT
        state,
        county,
        customers_out,
        run_start_time
    FROM
        eaglei_data
    WHERE
        customers_out IS NOT NULL
        AND customers_out > 0
        AND state = '{state}'
        AND county = '{county}'
    ORDER BY run_start_time
    """

    df = conn.sql(query).df()
    df['group'] = (df['run_start_time'] != df['run_start_time'].shift() + pd.Timedelta('15 minutes')).cumsum()

    summary = df.groupby('group').agg({
        'state': 'first',
        'county': 'first',
        'run_start_time': ['first', 'last'],
        'customers_out': ['min', 'max', 'mean']
    }).reset_index()

    summary.columns = ['group', 'state', 'county', 'start_time', 'end_time', 'min_customers', 'max_customers', 'avg_customers']
    summary['duration'] = summary['end_time'] - summary['start_time']

    return summary

def get_state_county_pairs(conn):
    query = """
    SELECT DISTINCT state, county
    FROM eaglei_data
    WHERE customers_out IS NOT NULL
    ORDER BY state, county
    """
    return conn.sql(query).df()

def process_all_data(db_path):
    results = []

    with duckdb.connect(database=db_path) as conn:
        pairs = get_state_county_pairs(conn)
        total_pairs = len(pairs)

        for idx, (_, row) in enumerate(pairs.iterrows(), 1):
            print(f"Processing {row['state']}, {row['county']} ({idx}/{total_pairs})")
            summary = process_state_county(conn, row['state'], row['county'])
            results.append(summary)

    final_summary = pd.concat(results, ignore_index=True)
    final_summary['group'] = range(len(final_summary))

    return final_summary

outage_summary = process_all_data(db_path)
# Out:
# Processing Alabama, Autauga (1/3095)
# Processing Alabama, Baldwin (2/3095)
# Processing Alabama, Barbour (3/3095)
# Processing Alabama, Bibb (4/3095)
# Processing Alabama, Blount (5/3095)
# Processing Alabama, Bullock (6/3095)
# Processing Alabama, Butler (7/3095)
# Processing Alabama, Calhoun (8/3095)
# Processing Alabama, Chambers (9/3095)
# Processing Alabama, Cherokee (10/3095)
# Processing Alabama, Chilton (11/3095)
# Processing Alabama, Choctaw (12/3095)
# Processing Alabama, Clarke (13/3095)
# Processing Alabama, Clay (14/3095)
# Processing Alabama, Cleburne (15/3095)
# Processing Alabama, Coffee (16/3095)
# Processing Alabama, Colbert (17/3095)
# Processing Alabama, Conecuh (18/3095)
# Processing Alabama, Coosa (19/3095)
# Processing Alabama, Covington (20/3095)
# Processing Alabama, Crenshaw (21/3095)
# Processing Alabama, Cullman (22/3095)
# Processing Alabama, Dale (23/3095)
# Processing Alabama, Dallas (24/3095)
# Processing Alabama, DeKalb (25/3095)
# Processing Alabama, Elmore (26/3095)
# Processing Alabama, Escambia (27/3095)
# Processing Alabama, Etowah (28/3095)
# Processing Alabama, Fayette (29/3095)
# Processing Alabama, Franklin (30/3095)
# Processing Alabama, Geneva (31/3095)
# Processing Alabama, Greene (32/3095)
# Processing Alabama, Hale (33/3095)
# Processing Alabama, Henry (34/3095)
# Processing Alabama, Houston (35/3095)
# Processing Alabama, Jackson (36/3095)
# Processing Alabama, Jefferson (37/3095)
# Processing Alabama, Lamar (38/3095)
# Processing Alabama, Lauderdale (39/3095)
# Processing Alabama, Lawrence (40/3095)
# Processing Alabama, Lee (41/3095)
# Processing Alabama, Limestone (42/3095)
# Processing Alabama, Lowndes (43/3095)
# Processing Alabama, Macon (44/3095)
# Processing Alabama, Madison (45/3095)
# Processing Alabama, Marengo (46/3095)
# Processing Alabama, Marion (47/3095)
# Processing Alabama, Marshall (48/3095)
# Processing Alabama, Mobile (49/3095)
# Processing Alabama, Monroe (50/3095)
# Processing Alabama, Montgomery (51/3095)
# Processing Alabama, Morgan (52/3095)
# Processing Alabama, Perry (53/3095)
# Processing Alabama, Pickens (54/3095)
# Processing Alabama, Pike (55/3095)
# Processing Alabama, Randolph (56/3095)
# Processing Alabama, Russell (57/3095)
# Processing Alabama, Shelby (58/3095)
# Processing Alabama, St. Clair (59/3095)
# Processing Alabama, Sumter (60/3095)
# Processing Alabama, Talladega (61/3095)
# Processing Alabama, Tallapoosa (62/3095)
# Processing Alabama, Tuscaloosa (63/3095)
# Processing Alabama, Walker (64/3095)
# Processing Alabama, Washington (65/3095)
# Processing Alabama, Wilcox (66/3095)
# Processing Alabama, Winston (67/3095)
# Processing Alaska, Anchorage (68/3095)
# Processing Alaska, Denali (69/3095)
# Processing Alaska, Fairbanks North Star (70/3095)
# Processing Alaska, Kenai Peninsula (71/3095)
# Processing Alaska, Matanuska-Susitna (72/3095)
# Processing Alaska, Southeast Fairbanks (73/3095)
# Processing Alaska, Valdez-Cordova (74/3095)
# Processing Alaska, Yukon-Koyukuk (75/3095)
# Processing Arizona, Apache (76/3095)
# Processing Arizona, Cochise (77/3095)
# Processing Arizona, Coconino (78/3095)
# Processing Arizona, Gila (79/3095)
# Processing Arizona, Graham (80/3095)
# Processing Arizona, Greenlee (81/3095)
# Processing Arizona, La Paz (82/3095)
# Processing Arizona, Maricopa (83/3095)
# Processing Arizona, Mohave (84/3095)
# Processing Arizona, Navajo (85/3095)
# Processing Arizona, Pima (86/3095)
# Processing Arizona, Pinal (87/3095)
# Processing Arizona, Santa Cruz (88/3095)
# Processing Arizona, Yavapai (89/3095)
# Processing Arizona, Yuma (90/3095)
# Processing Arkansas, Arkansas (91/3095)
# Processing Arkansas, Ashley (92/3095)
# Processing Arkansas, Baxter (93/3095)
# Processing Arkansas, Benton (94/3095)
# Processing Arkansas, Boone (95/3095)
# Processing Arkansas, Bradley (96/3095)
# Processing Arkansas, Calhoun (97/3095)
# Processing Arkansas, Carroll (98/3095)
# Processing Arkansas, Chicot (99/3095)
# Processing Arkansas, Clark (100/3095)
# Processing Arkansas, Clay (101/3095)
# Processing Arkansas, Cleburne (102/3095)
# Processing Arkansas, Cleveland (103/3095)
# Processing Arkansas, Columbia (104/3095)
# Processing Arkansas, Conway (105/3095)
# Processing Arkansas, Craighead (106/3095)
# Processing Arkansas, Crawford (107/3095)
# Processing Arkansas, Crittenden (108/3095)
# Processing Arkansas, Cross (109/3095)
# Processing Arkansas, Dallas (110/3095)
# Processing Arkansas, Desha (111/3095)
# Processing Arkansas, Drew (112/3095)
# Processing Arkansas, Faulkner (113/3095)
# Processing Arkansas, Franklin (114/3095)
# Processing Arkansas, Fulton (115/3095)
# Processing Arkansas, Garland (116/3095)
# Processing Arkansas, Grant (117/3095)
# Processing Arkansas, Greene (118/3095)
# Processing Arkansas, Hempstead (119/3095)
# Processing Arkansas, Hot Spring (120/3095)
# Processing Arkansas, Howard (121/3095)
# Processing Arkansas, Independence (122/3095)
# Processing Arkansas, Izard (123/3095)
# Processing Arkansas, Jackson (124/3095)
# Processing Arkansas, Jefferson (125/3095)
# Processing Arkansas, Johnson (126/3095)
# Processing Arkansas, Lafayette (127/3095)
# Processing Arkansas, Lawrence (128/3095)
# Processing Arkansas, Lee (129/3095)
# Processing Arkansas, Lincoln (130/3095)
# Processing Arkansas, Little River (131/3095)
# Processing Arkansas, Logan (132/3095)
# Processing Arkansas, Lonoke (133/3095)
# Processing Arkansas, Madison (134/3095)
# Processing Arkansas, Marion (135/3095)
# Processing Arkansas, Miller (136/3095)
# Processing Arkansas, Mississippi (137/3095)
# Processing Arkansas, Monroe (138/3095)
# Processing Arkansas, Montgomery (139/3095)
# Processing Arkansas, Nevada (140/3095)
# Processing Arkansas, Newton (141/3095)
# Processing Arkansas, Ouachita (142/3095)
# Processing Arkansas, Perry (143/3095)
# Processing Arkansas, Phillips (144/3095)
# Processing Arkansas, Pike (145/3095)
# Processing Arkansas, Poinsett (146/3095)
# Processing Arkansas, Polk (147/3095)
# Processing Arkansas, Pope (148/3095)
# Processing Arkansas, Prairie (149/3095)
# Processing Arkansas, Pulaski (150/3095)
# Processing Arkansas, Randolph (151/3095)
# Processing Arkansas, Saline (152/3095)
# Processing Arkansas, Scott (153/3095)
# Processing Arkansas, Searcy (154/3095)
# Processing Arkansas, Sebastian (155/3095)
# Processing Arkansas, Sevier (156/3095)
# Processing Arkansas, Sharp (157/3095)
# Processing Arkansas, St. Francis (158/3095)
# Processing Arkansas, Stone (159/3095)
# Processing Arkansas, Union (160/3095)
# Processing Arkansas, Van Buren (161/3095)
# Processing Arkansas, Washington (162/3095)
# Processing Arkansas, White (163/3095)
# Processing Arkansas, Woodruff (164/3095)
# Processing Arkansas, Yell (165/3095)
# Processing California, Alameda (166/3095)
# Processing California, Alpine (167/3095)
# Processing California, Amador (168/3095)
# Processing California, Butte (169/3095)
# Processing California, Calaveras (170/3095)
# Processing California, Colusa (171/3095)
# Processing California, Contra Costa (172/3095)
# Processing California, Del Norte (173/3095)
# Processing California, El Dorado (174/3095)
# Processing California, Fresno (175/3095)
# Processing California, Glenn (176/3095)
# Processing California, Humboldt (177/3095)
# Processing California, Imperial (178/3095)
# Processing California, Inyo (179/3095)
# Processing California, Kern (180/3095)
# Processing California, Kings (181/3095)
# Processing California, Lake (182/3095)
# Processing California, Lassen (183/3095)
# Processing California, Los Angeles (184/3095)
# Processing California, Madera (185/3095)
# Processing California, Marin (186/3095)
# Processing California, Mariposa (187/3095)
# Processing California, Mendocino (188/3095)
# Processing California, Merced (189/3095)
# Processing California, Modoc (190/3095)
# Processing California, Mono (191/3095)
# Processing California, Monterey (192/3095)
# Processing California, Napa (193/3095)
# Processing California, Nevada (194/3095)
# Processing California, Orange (195/3095)
# Processing California, Placer (196/3095)
# Processing California, Plumas (197/3095)
# Processing California, Riverside (198/3095)
# Processing California, Sacramento (199/3095)
# Processing California, San Benito (200/3095)
# Processing California, San Bernardino (201/3095)
# Processing California, San Diego (202/3095)
# Processing California, San Francisco (203/3095)
# Processing California, San Joaquin (204/3095)
# Processing California, San Luis Obispo (205/3095)
# Processing California, San Mateo (206/3095)
# Processing California, Santa Barbara (207/3095)
# Processing California, Santa Clara (208/3095)
# Processing California, Santa Cruz (209/3095)
# Processing California, Shasta (210/3095)
# Processing California, Sierra (211/3095)
# Processing California, Siskiyou (212/3095)
# Processing California, Solano (213/3095)
# Processing California, Sonoma (214/3095)
# Processing California, Stanislaus (215/3095)
# Processing California, Sutter (216/3095)
# Processing California, Tehama (217/3095)
# Processing California, Trinity (218/3095)
# Processing California, Tulare (219/3095)
# Processing California, Tuolumne (220/3095)
# Processing California, Ventura (221/3095)
# Processing California, Yolo (222/3095)
# Processing California, Yuba (223/3095)
# Processing Colorado, Adams (224/3095)
# Processing Colorado, Alamosa (225/3095)
# Processing Colorado, Arapahoe (226/3095)
# Processing Colorado, Archuleta (227/3095)
# Processing Colorado, Baca (228/3095)
# Processing Colorado, Bent (229/3095)
# Processing Colorado, Boulder (230/3095)
# Processing Colorado, Broomfield (231/3095)
# Processing Colorado, Chaffee (232/3095)
# Processing Colorado, Cheyenne (233/3095)
# Processing Colorado, Clear Creek (234/3095)
# Processing Colorado, Conejos (235/3095)
# Processing Colorado, Costilla (236/3095)
# Processing Colorado, Crowley (237/3095)
# Processing Colorado, Custer (238/3095)
# Processing Colorado, Delta (239/3095)
# Processing Colorado, Denver (240/3095)
# Processing Colorado, Dolores (241/3095)
# Processing Colorado, Douglas (242/3095)
# Processing Colorado, Eagle (243/3095)
# Processing Colorado, El Paso (244/3095)
# Processing Colorado, Elbert (245/3095)
# Processing Colorado, Fremont (246/3095)
# Processing Colorado, Garfield (247/3095)
# Processing Colorado, Gilpin (248/3095)
# Processing Colorado, Grand (249/3095)
# Processing Colorado, Gunnison (250/3095)
# Processing Colorado, Hinsdale (251/3095)
# Processing Colorado, Huerfano (252/3095)
# Processing Colorado, Jackson (253/3095)
# Processing Colorado, Jefferson (254/3095)
# Processing Colorado, Kiowa (255/3095)
# Processing Colorado, Kit Carson (256/3095)
# Processing Colorado, La Plata (257/3095)
# Processing Colorado, Lake (258/3095)
# Processing Colorado, Larimer (259/3095)
# Processing Colorado, Las Animas (260/3095)
# Processing Colorado, Lincoln (261/3095)
# Processing Colorado, Logan (262/3095)
# Processing Colorado, Mesa (263/3095)
# Processing Colorado, Mineral (264/3095)
# Processing Colorado, Moffat (265/3095)
# Processing Colorado, Montezuma (266/3095)
# Processing Colorado, Montrose (267/3095)
# Processing Colorado, Morgan (268/3095)
# Processing Colorado, Otero (269/3095)
# Processing Colorado, Ouray (270/3095)
# Processing Colorado, Park (271/3095)
# Processing Colorado, Pitkin (272/3095)
# Processing Colorado, Prowers (273/3095)
# Processing Colorado, Pueblo (274/3095)
# Processing Colorado, Rio Blanco (275/3095)
# Processing Colorado, Rio Grande (276/3095)
# Processing Colorado, Routt (277/3095)
# Processing Colorado, Saguache (278/3095)
# Processing Colorado, San Juan (279/3095)
# Processing Colorado, San Miguel (280/3095)
# Processing Colorado, Sedgwick (281/3095)
# Processing Colorado, Summit (282/3095)
# Processing Colorado, Teller (283/3095)
# Processing Colorado, Washington (284/3095)
# Processing Colorado, Weld (285/3095)
# Processing Colorado, Yuma (286/3095)
# Processing Connecticut, Fairfield (287/3095)
# Processing Connecticut, Hartford (288/3095)
# Processing Connecticut, Litchfield (289/3095)
# Processing Connecticut, Middlesex (290/3095)
# Processing Connecticut, New Haven (291/3095)
# Processing Connecticut, New London (292/3095)
# Processing Connecticut, Tolland (293/3095)
# Processing Connecticut, Windham (294/3095)
# Processing Delaware, Kent (295/3095)
# Processing Delaware, New Castle (296/3095)
# Processing Delaware, Sussex (297/3095)
# Processing District of Columbia, District of Columbia (298/3095)
# Processing Florida, Alachua (299/3095)
# Processing Florida, Baker (300/3095)
# Processing Florida, Bay (301/3095)
# Processing Florida, Bradford (302/3095)
# Processing Florida, Brevard (303/3095)
# Processing Florida, Broward (304/3095)
# Processing Florida, Calhoun (305/3095)
# Processing Florida, Charlotte (306/3095)
# Processing Florida, Citrus (307/3095)
# Processing Florida, Clay (308/3095)
# Processing Florida, Collier (309/3095)
# Processing Florida, Columbia (310/3095)
# Processing Florida, DeSoto (311/3095)
# Processing Florida, Dixie (312/3095)
# Processing Florida, Duval (313/3095)
# Processing Florida, Escambia (314/3095)
# Processing Florida, Flagler (315/3095)
# Processing Florida, Franklin (316/3095)
# Processing Florida, Gadsden (317/3095)
# Processing Florida, Gilchrist (318/3095)
# Processing Florida, Glades (319/3095)
# Processing Florida, Gulf (320/3095)
# Processing Florida, Hamilton (321/3095)
# Processing Florida, Hardee (322/3095)
# Processing Florida, Hendry (323/3095)
# Processing Florida, Hernando (324/3095)
# Processing Florida, Highlands (325/3095)
# Processing Florida, Hillsborough (326/3095)
# Processing Florida, Holmes (327/3095)
# Processing Florida, Indian River (328/3095)
# Processing Florida, Jackson (329/3095)
# Processing Florida, Jefferson (330/3095)
# Processing Florida, Lafayette (331/3095)
# Processing Florida, Lake (332/3095)
# Processing Florida, Lee (333/3095)
# Processing Florida, Leon (334/3095)
# Processing Florida, Levy (335/3095)
# Processing Florida, Liberty (336/3095)
# Processing Florida, Madison (337/3095)
# Processing Florida, Manatee (338/3095)
# Processing Florida, Marion (339/3095)
# Processing Florida, Martin (340/3095)
# Processing Florida, Miami-Dade (341/3095)
# Processing Florida, Monroe (342/3095)
# Processing Florida, Nassau (343/3095)
# Processing Florida, Okaloosa (344/3095)
# Processing Florida, Okeechobee (345/3095)
# Processing Florida, Orange (346/3095)
# Processing Florida, Osceola (347/3095)
# Processing Florida, Palm Beach (348/3095)
# Processing Florida, Pasco (349/3095)
# Processing Florida, Pinellas (350/3095)
# Processing Florida, Polk (351/3095)
# Processing Florida, Putnam (352/3095)
# Processing Florida, Santa Rosa (353/3095)
# Processing Florida, Sarasota (354/3095)
# Processing Florida, Seminole (355/3095)
# Processing Florida, St. Johns (356/3095)
# Processing Florida, St. Lucie (357/3095)
# Processing Florida, Sumter (358/3095)
# Processing Florida, Suwannee (359/3095)
# Processing Florida, Taylor (360/3095)
# Processing Florida, Union (361/3095)
# Processing Florida, Volusia (362/3095)
# Processing Florida, Wakulla (363/3095)
# Processing Florida, Walton (364/3095)
# Processing Florida, Washington (365/3095)
# Processing Georgia, Appling (366/3095)
# Processing Georgia, Atkinson (367/3095)
# Processing Georgia, Bacon (368/3095)
# Processing Georgia, Baker (369/3095)
# Processing Georgia, Baldwin (370/3095)
# Processing Georgia, Banks (371/3095)
# Processing Georgia, Barrow (372/3095)
# Processing Georgia, Bartow (373/3095)
# Processing Georgia, Ben Hill (374/3095)
# Processing Georgia, Berrien (375/3095)
# Processing Georgia, Bibb (376/3095)
# Processing Georgia, Bleckley (377/3095)
# Processing Georgia, Brantley (378/3095)
# Processing Georgia, Brooks (379/3095)
# Processing Georgia, Bryan (380/3095)
# Processing Georgia, Bulloch (381/3095)
# Processing Georgia, Burke (382/3095)
# Processing Georgia, Butts (383/3095)
# Processing Georgia, Calhoun (384/3095)
# Processing Georgia, Camden (385/3095)
# Processing Georgia, Candler (386/3095)
# Processing Georgia, Carroll (387/3095)
# Processing Georgia, Catoosa (388/3095)
# Processing Georgia, Charlton (389/3095)
# Processing Georgia, Chatham (390/3095)
# Processing Georgia, Chattahoochee (391/3095)
# Processing Georgia, Chattooga (392/3095)
# Processing Georgia, Cherokee (393/3095)
# Processing Georgia, Clarke (394/3095)
# Processing Georgia, Clay (395/3095)
# Processing Georgia, Clayton (396/3095)
# Processing Georgia, Clinch (397/3095)
# Processing Georgia, Cobb (398/3095)
# Processing Georgia, Coffee (399/3095)
# Processing Georgia, Colquitt (400/3095)
# Processing Georgia, Columbia (401/3095)
# Processing Georgia, Cook (402/3095)
# Processing Georgia, Coweta (403/3095)
# Processing Georgia, Crawford (404/3095)
# Processing Georgia, Crisp (405/3095)
# Processing Georgia, Dade (406/3095)
# Processing Georgia, Dawson (407/3095)
# Processing Georgia, DeKalb (408/3095)
# Processing Georgia, Decatur (409/3095)
# Processing Georgia, Dodge (410/3095)
# Processing Georgia, Dooly (411/3095)
# Processing Georgia, Dougherty (412/3095)
# Processing Georgia, Douglas (413/3095)
# Processing Georgia, Early (414/3095)
# Processing Georgia, Echols (415/3095)
# Processing Georgia, Effingham (416/3095)
# Processing Georgia, Elbert (417/3095)
# Processing Georgia, Emanuel (418/3095)
# Processing Georgia, Evans (419/3095)
# Processing Georgia, Fannin (420/3095)
# Processing Georgia, Fayette (421/3095)
# Processing Georgia, Floyd (422/3095)
# Processing Georgia, Forsyth (423/3095)
# Processing Georgia, Franklin (424/3095)
# Processing Georgia, Fulton (425/3095)
# Processing Georgia, Gilmer (426/3095)
# Processing Georgia, Glascock (427/3095)
# Processing Georgia, Glynn (428/3095)
# Processing Georgia, Gordon (429/3095)
# Processing Georgia, Grady (430/3095)
# Processing Georgia, Greene (431/3095)
# Processing Georgia, Gwinnett (432/3095)
# Processing Georgia, Habersham (433/3095)
# Processing Georgia, Hall (434/3095)
# Processing Georgia, Hancock (435/3095)
# Processing Georgia, Haralson (436/3095)
# Processing Georgia, Harris (437/3095)
# Processing Georgia, Hart (438/3095)
# Processing Georgia, Heard (439/3095)
# Processing Georgia, Henry (440/3095)
# Processing Georgia, Houston (441/3095)
# Processing Georgia, Irwin (442/3095)
# Processing Georgia, Jackson (443/3095)
# Processing Georgia, Jasper (444/3095)
# Processing Georgia, Jeff Davis (445/3095)
# Processing Georgia, Jefferson (446/3095)
# Processing Georgia, Jenkins (447/3095)
# Processing Georgia, Johnson (448/3095)
# Processing Georgia, Jones (449/3095)
# Processing Georgia, Lamar (450/3095)
# Processing Georgia, Lanier (451/3095)
# Processing Georgia, Laurens (452/3095)
# Processing Georgia, Lee (453/3095)
# Processing Georgia, Liberty (454/3095)
# Processing Georgia, Lincoln (455/3095)
# Processing Georgia, Long (456/3095)
# Processing Georgia, Lowndes (457/3095)
# Processing Georgia, Lumpkin (458/3095)
# Processing Georgia, Macon (459/3095)
# Processing Georgia, Madison (460/3095)
# Processing Georgia, Marion (461/3095)
# Processing Georgia, McDuffie (462/3095)
# Processing Georgia, McIntosh (463/3095)
# Processing Georgia, Meriwether (464/3095)
# Processing Georgia, Miller (465/3095)
# Processing Georgia, Mitchell (466/3095)
# Processing Georgia, Monroe (467/3095)
# Processing Georgia, Montgomery (468/3095)
# Processing Georgia, Morgan (469/3095)
# Processing Georgia, Murray (470/3095)
# Processing Georgia, Muscogee (471/3095)
# Processing Georgia, Newton (472/3095)
# Processing Georgia, Oconee (473/3095)
# Processing Georgia, Oglethorpe (474/3095)
# Processing Georgia, Paulding (475/3095)
# Processing Georgia, Peach (476/3095)
# Processing Georgia, Pickens (477/3095)
# Processing Georgia, Pierce (478/3095)
# Processing Georgia, Pike (479/3095)
# Processing Georgia, Polk (480/3095)
# Processing Georgia, Pulaski (481/3095)
# Processing Georgia, Putnam (482/3095)
# Processing Georgia, Quitman (483/3095)
# Processing Georgia, Rabun (484/3095)
# Processing Georgia, Randolph (485/3095)
# Processing Georgia, Richmond (486/3095)
# Processing Georgia, Rockdale (487/3095)
# Processing Georgia, Schley (488/3095)
# Processing Georgia, Screven (489/3095)
# Processing Georgia, Seminole (490/3095)
# Processing Georgia, Spalding (491/3095)
# Processing Georgia, Stephens (492/3095)
# Processing Georgia, Stewart (493/3095)
# Processing Georgia, Sumter (494/3095)
# Processing Georgia, Talbot (495/3095)
# Processing Georgia, Taliaferro (496/3095)
# Processing Georgia, Tattnall (497/3095)
# Processing Georgia, Taylor (498/3095)
# Processing Georgia, Telfair (499/3095)
# Processing Georgia, Terrell (500/3095)
# Processing Georgia, Thomas (501/3095)
# Processing Georgia, Tift (502/3095)
# Processing Georgia, Toombs (503/3095)
# Processing Georgia, Towns (504/3095)
# Processing Georgia, Treutlen (505/3095)
# Processing Georgia, Troup (506/3095)
# Processing Georgia, Turner (507/3095)
# Processing Georgia, Twiggs (508/3095)
# Processing Georgia, Union (509/3095)
# Processing Georgia, Upson (510/3095)
# Processing Georgia, Walker (511/3095)
# Processing Georgia, Walton (512/3095)
# Processing Georgia, Ware (513/3095)
# Processing Georgia, Warren (514/3095)
# Processing Georgia, Washington (515/3095)
# Processing Georgia, Wayne (516/3095)
# Processing Georgia, Webster (517/3095)
# Processing Georgia, Wheeler (518/3095)
# Processing Georgia, White (519/3095)
# Processing Georgia, Whitfield (520/3095)
# Processing Georgia, Wilcox (521/3095)
# Processing Georgia, Wilkes (522/3095)
# Processing Georgia, Wilkinson (523/3095)
# Processing Georgia, Worth (524/3095)
# Processing Hawaii, Hawaii (525/3095)
# Processing Hawaii, Honolulu (526/3095)
# Processing Hawaii, Kalawao (527/3095)
# Processing Hawaii, Kauai (528/3095)
# Processing Hawaii, Maui (529/3095)
# Processing Idaho, Ada (530/3095)
# Processing Idaho, Adams (531/3095)
# Processing Idaho, Bannock (532/3095)
# Processing Idaho, Bear Lake (533/3095)
# Processing Idaho, Benewah (534/3095)
# Processing Idaho, Bingham (535/3095)
# Processing Idaho, Blaine (536/3095)
# Processing Idaho, Boise (537/3095)
# Processing Idaho, Bonner (538/3095)
# Processing Idaho, Bonneville (539/3095)
# Processing Idaho, Boundary (540/3095)
# Processing Idaho, Butte (541/3095)
# Processing Idaho, Camas (542/3095)
# Processing Idaho, Canyon (543/3095)
# Processing Idaho, Caribou (544/3095)
# Processing Idaho, Cassia (545/3095)
# Processing Idaho, Clark (546/3095)
# Processing Idaho, Clearwater (547/3095)
# Processing Idaho, Custer (548/3095)
# Processing Idaho, Elmore (549/3095)
# Processing Idaho, Franklin (550/3095)
# Processing Idaho, Fremont (551/3095)
# Processing Idaho, Gem (552/3095)
# Processing Idaho, Gooding (553/3095)
# Processing Idaho, Idaho (554/3095)
# Processing Idaho, Jefferson (555/3095)
# Processing Idaho, Jerome (556/3095)
# Processing Idaho, Kootenai (557/3095)
# Processing Idaho, Latah (558/3095)
# Processing Idaho, Lemhi (559/3095)
# Processing Idaho, Lewis (560/3095)
# Processing Idaho, Lincoln (561/3095)
# Processing Idaho, Madison (562/3095)
# Processing Idaho, Minidoka (563/3095)
# Processing Idaho, Nez Perce (564/3095)
# Processing Idaho, Oneida (565/3095)
# Processing Idaho, Owyhee (566/3095)
# Processing Idaho, Payette (567/3095)
# Processing Idaho, Power (568/3095)
# Processing Idaho, Shoshone (569/3095)
# Processing Idaho, Teton (570/3095)
# Processing Idaho, Twin Falls (571/3095)
# Processing Idaho, Valley (572/3095)
# Processing Idaho, Washington (573/3095)
# Processing Illinois, Adams (574/3095)
# Processing Illinois, Alexander (575/3095)
# Processing Illinois, Bond (576/3095)
# Processing Illinois, Boone (577/3095)
# Processing Illinois, Brown (578/3095)
# Processing Illinois, Bureau (579/3095)
# Processing Illinois, Calhoun (580/3095)
# Processing Illinois, Carroll (581/3095)
# Processing Illinois, Cass (582/3095)
# Processing Illinois, Champaign (583/3095)
# Processing Illinois, Christian (584/3095)
# Processing Illinois, Clark (585/3095)
# Processing Illinois, Clay (586/3095)
# Processing Illinois, Clinton (587/3095)
# Processing Illinois, Coles (588/3095)
# Processing Illinois, Cook (589/3095)
# Processing Illinois, Crawford (590/3095)
# Processing Illinois, Cumberland (591/3095)
# Processing Illinois, De Witt (592/3095)
# Processing Illinois, DeKalb (593/3095)
# Processing Illinois, Douglas (594/3095)
# Processing Illinois, DuPage (595/3095)
# Processing Illinois, Edgar (596/3095)
# Processing Illinois, Edwards (597/3095)
# Processing Illinois, Effingham (598/3095)
# Processing Illinois, Fayette (599/3095)
# Processing Illinois, Ford (600/3095)
# Processing Illinois, Franklin (601/3095)
# Processing Illinois, Fulton (602/3095)
# Processing Illinois, Gallatin (603/3095)
# Processing Illinois, Greene (604/3095)
# Processing Illinois, Grundy (605/3095)
# Processing Illinois, Hamilton (606/3095)
# Processing Illinois, Hancock (607/3095)
# Processing Illinois, Hardin (608/3095)
# Processing Illinois, Henderson (609/3095)
# Processing Illinois, Henry (610/3095)
# Processing Illinois, Iroquois (611/3095)
# Processing Illinois, Jackson (612/3095)
# Processing Illinois, Jasper (613/3095)
# Processing Illinois, Jefferson (614/3095)
# Processing Illinois, Jersey (615/3095)
# Processing Illinois, Jo Daviess (616/3095)
# Processing Illinois, Johnson (617/3095)
# Processing Illinois, Kane (618/3095)
# Processing Illinois, Kankakee (619/3095)
# Processing Illinois, Kendall (620/3095)
# Processing Illinois, Knox (621/3095)
# Processing Illinois, LaSalle (622/3095)
# Processing Illinois, Lake (623/3095)
# Processing Illinois, Lawrence (624/3095)
# Processing Illinois, Lee (625/3095)
# Processing Illinois, Livingston (626/3095)
# Processing Illinois, Logan (627/3095)
# Processing Illinois, Macon (628/3095)
# Processing Illinois, Macoupin (629/3095)
# Processing Illinois, Madison (630/3095)
# Processing Illinois, Marion (631/3095)
# Processing Illinois, Marshall (632/3095)
# Processing Illinois, Mason (633/3095)
# Processing Illinois, Massac (634/3095)
# Processing Illinois, McDonough (635/3095)
# Processing Illinois, McHenry (636/3095)
# Processing Illinois, McLean (637/3095)
# Processing Illinois, Menard (638/3095)
# Processing Illinois, Mercer (639/3095)
# Processing Illinois, Monroe (640/3095)
# Processing Illinois, Montgomery (641/3095)
# Processing Illinois, Morgan (642/3095)
# Processing Illinois, Moultrie (643/3095)
# Processing Illinois, Ogle (644/3095)
# Processing Illinois, Peoria (645/3095)
# Processing Illinois, Perry (646/3095)
# Processing Illinois, Piatt (647/3095)
# Processing Illinois, Pike (648/3095)
# Processing Illinois, Pope (649/3095)
# Processing Illinois, Pulaski (650/3095)
# Processing Illinois, Putnam (651/3095)
# Processing Illinois, Randolph (652/3095)
# Processing Illinois, Richland (653/3095)
# Processing Illinois, Rock Island (654/3095)
# Processing Illinois, Saline (655/3095)
# Processing Illinois, Sangamon (656/3095)
# Processing Illinois, Schuyler (657/3095)
# Processing Illinois, Scott (658/3095)
# Processing Illinois, Shelby (659/3095)
# Processing Illinois, St. Clair (660/3095)
# Processing Illinois, Stark (661/3095)
# Processing Illinois, Stephenson (662/3095)
# Processing Illinois, Tazewell (663/3095)
# Processing Illinois, Union (664/3095)
# Processing Illinois, Vermilion (665/3095)
# Processing Illinois, Wabash (666/3095)
# Processing Illinois, Warren (667/3095)
# Processing Illinois, Washington (668/3095)
# Processing Illinois, Wayne (669/3095)
# Processing Illinois, White (670/3095)
# Processing Illinois, Whiteside (671/3095)
# Processing Illinois, Will (672/3095)
# Processing Illinois, Williamson (673/3095)
# Processing Illinois, Winnebago (674/3095)
# Processing Illinois, Woodford (675/3095)
# Processing Indiana, Adams (676/3095)
# Processing Indiana, Allen (677/3095)
# Processing Indiana, Bartholomew (678/3095)
# Processing Indiana, Benton (679/3095)
# Processing Indiana, Blackford (680/3095)
# Processing Indiana, Boone (681/3095)
# Processing Indiana, Brown (682/3095)
# Processing Indiana, Carroll (683/3095)
# Processing Indiana, Cass (684/3095)
# Processing Indiana, Clark (685/3095)
# Processing Indiana, Clay (686/3095)
# Processing Indiana, Clinton (687/3095)
# Processing Indiana, Crawford (688/3095)
# Processing Indiana, Daviess (689/3095)
# Processing Indiana, DeKalb (690/3095)
# Processing Indiana, Dearborn (691/3095)
# Processing Indiana, Decatur (692/3095)
# Processing Indiana, Delaware (693/3095)
# Processing Indiana, Dubois (694/3095)
# Processing Indiana, Elkhart (695/3095)
# Processing Indiana, Fayette (696/3095)
# Processing Indiana, Floyd (697/3095)
# Processing Indiana, Fountain (698/3095)
# Processing Indiana, Franklin (699/3095)
# Processing Indiana, Fulton (700/3095)
# Processing Indiana, Gibson (701/3095)
# Processing Indiana, Grant (702/3095)
# Processing Indiana, Greene (703/3095)
# Processing Indiana, Hamilton (704/3095)
# Processing Indiana, Hancock (705/3095)
# Processing Indiana, Harrison (706/3095)
# Processing Indiana, Hendricks (707/3095)
# Processing Indiana, Henry (708/3095)
# Processing Indiana, Howard (709/3095)
# Processing Indiana, Huntington (710/3095)
# Processing Indiana, Jackson (711/3095)
# Processing Indiana, Jasper (712/3095)
# Processing Indiana, Jay (713/3095)
# Processing Indiana, Jefferson (714/3095)
# Processing Indiana, Jennings (715/3095)
# Processing Indiana, Johnson (716/3095)
# Processing Indiana, Knox (717/3095)
# Processing Indiana, Kosciusko (718/3095)
# Processing Indiana, LaGrange (719/3095)
# Processing Indiana, LaPorte (720/3095)
# Processing Indiana, Lake (721/3095)
# Processing Indiana, Lawrence (722/3095)
# Processing Indiana, Madison (723/3095)
# Processing Indiana, Marion (724/3095)
# Processing Indiana, Marshall (725/3095)
# Processing Indiana, Martin (726/3095)
# Processing Indiana, Miami (727/3095)
# Processing Indiana, Monroe (728/3095)
# Processing Indiana, Montgomery (729/3095)
# Processing Indiana, Morgan (730/3095)
# Processing Indiana, Newton (731/3095)
# Processing Indiana, Noble (732/3095)
# Processing Indiana, Ohio (733/3095)
# Processing Indiana, Orange (734/3095)
# Processing Indiana, Owen (735/3095)
# Processing Indiana, Parke (736/3095)
# Processing Indiana, Perry (737/3095)
# Processing Indiana, Pike (738/3095)
# Processing Indiana, Porter (739/3095)
# Processing Indiana, Posey (740/3095)
# Processing Indiana, Pulaski (741/3095)
# Processing Indiana, Putnam (742/3095)
# Processing Indiana, Randolph (743/3095)
# Processing Indiana, Ripley (744/3095)
# Processing Indiana, Rush (745/3095)
# Processing Indiana, Scott (746/3095)
# Processing Indiana, Shelby (747/3095)
# Processing Indiana, Spencer (748/3095)
# Processing Indiana, St. Joseph (749/3095)
# Processing Indiana, Starke (750/3095)
# Processing Indiana, Steuben (751/3095)
# Processing Indiana, Sullivan (752/3095)
# Processing Indiana, Switzerland (753/3095)
# Processing Indiana, Tippecanoe (754/3095)
# Processing Indiana, Tipton (755/3095)
# Processing Indiana, Union (756/3095)
# Processing Indiana, Vanderburgh (757/3095)
# Processing Indiana, Vermillion (758/3095)
# Processing Indiana, Vigo (759/3095)
# Processing Indiana, Wabash (760/3095)
# Processing Indiana, Warren (761/3095)
# Processing Indiana, Warrick (762/3095)
# Processing Indiana, Washington (763/3095)
# Processing Indiana, Wayne (764/3095)
# Processing Indiana, Wells (765/3095)
# Processing Indiana, White (766/3095)
# Processing Indiana, Whitley (767/3095)
# Processing Iowa, Adair (768/3095)
# Processing Iowa, Adams (769/3095)
# Processing Iowa, Allamakee (770/3095)
# Processing Iowa, Appanoose (771/3095)
# Processing Iowa, Audubon (772/3095)
# Processing Iowa, Benton (773/3095)
# Processing Iowa, Black Hawk (774/3095)
# Processing Iowa, Boone (775/3095)
# Processing Iowa, Bremer (776/3095)
# Processing Iowa, Buchanan (777/3095)
# Processing Iowa, Buena Vista (778/3095)
# Processing Iowa, Butler (779/3095)
# Processing Iowa, Calhoun (780/3095)
# Processing Iowa, Carroll (781/3095)
# Processing Iowa, Cass (782/3095)
# Processing Iowa, Cedar (783/3095)
# Processing Iowa, Cerro Gordo (784/3095)
# Processing Iowa, Cherokee (785/3095)
# Processing Iowa, Chickasaw (786/3095)
# Processing Iowa, Clarke (787/3095)
# Processing Iowa, Clay (788/3095)
# Processing Iowa, Clayton (789/3095)
# Processing Iowa, Clinton (790/3095)
# Processing Iowa, Crawford (791/3095)
# Processing Iowa, Dallas (792/3095)
# Processing Iowa, Davis (793/3095)
# Processing Iowa, Decatur (794/3095)
# Processing Iowa, Delaware (795/3095)
# Processing Iowa, Des Moines (796/3095)
# Processing Iowa, Dickinson (797/3095)
# Processing Iowa, Dubuque (798/3095)
# Processing Iowa, Emmet (799/3095)
# Processing Iowa, Fayette (800/3095)
# Processing Iowa, Floyd (801/3095)
# Processing Iowa, Franklin (802/3095)
# Processing Iowa, Fremont (803/3095)
# Processing Iowa, Greene (804/3095)
# Processing Iowa, Grundy (805/3095)
# Processing Iowa, Guthrie (806/3095)
# Processing Iowa, Hamilton (807/3095)
# Processing Iowa, Hancock (808/3095)
# Processing Iowa, Hardin (809/3095)
# Processing Iowa, Harrison (810/3095)
# Processing Iowa, Henry (811/3095)
# Processing Iowa, Howard (812/3095)
# Processing Iowa, Humboldt (813/3095)
# Processing Iowa, Ida (814/3095)
# Processing Iowa, Iowa (815/3095)
# Processing Iowa, Jackson (816/3095)
# Processing Iowa, Jasper (817/3095)
# Processing Iowa, Jefferson (818/3095)
# Processing Iowa, Johnson (819/3095)
# Processing Iowa, Jones (820/3095)
# Processing Iowa, Keokuk (821/3095)
# Processing Iowa, Kossuth (822/3095)
# Processing Iowa, Lee (823/3095)
# Processing Iowa, Linn (824/3095)
# Processing Iowa, Louisa (825/3095)
# Processing Iowa, Lucas (826/3095)
# Processing Iowa, Lyon (827/3095)
# Processing Iowa, Madison (828/3095)
# Processing Iowa, Mahaska (829/3095)
# Processing Iowa, Marion (830/3095)
# Processing Iowa, Marshall (831/3095)
# Processing Iowa, Mills (832/3095)
# Processing Iowa, Mitchell (833/3095)
# Processing Iowa, Monona (834/3095)
# Processing Iowa, Monroe (835/3095)
# Processing Iowa, Montgomery (836/3095)
# Processing Iowa, Muscatine (837/3095)
# Processing Iowa, O'Brien (838/3095)
# Processing Iowa, Osceola (839/3095)
# Processing Iowa, Page (840/3095)
# Processing Iowa, Palo Alto (841/3095)
# Processing Iowa, Plymouth (842/3095)
# Processing Iowa, Pocahontas (843/3095)
# Processing Iowa, Polk (844/3095)
# Processing Iowa, Pottawattamie (845/3095)
# Processing Iowa, Poweshiek (846/3095)
# Processing Iowa, Ringgold (847/3095)
# Processing Iowa, Sac (848/3095)
# Processing Iowa, Scott (849/3095)
# Processing Iowa, Shelby (850/3095)
# Processing Iowa, Sioux (851/3095)
# Processing Iowa, Story (852/3095)
# Processing Iowa, Tama (853/3095)
# Processing Iowa, Taylor (854/3095)
# Processing Iowa, Union (855/3095)
# Processing Iowa, Van Buren (856/3095)
# Processing Iowa, Wapello (857/3095)
# Processing Iowa, Warren (858/3095)
# Processing Iowa, Washington (859/3095)
# Processing Iowa, Wayne (860/3095)
# Processing Iowa, Webster (861/3095)
# Processing Iowa, Winnebago (862/3095)
# Processing Iowa, Winneshiek (863/3095)
# Processing Iowa, Woodbury (864/3095)
# Processing Iowa, Worth (865/3095)
# Processing Iowa, Wright (866/3095)
# Processing Kansas, Allen (867/3095)
# Processing Kansas, Anderson (868/3095)
# Processing Kansas, Atchison (869/3095)
# Processing Kansas, Barber (870/3095)
# Processing Kansas, Barton (871/3095)
# Processing Kansas, Bourbon (872/3095)
# Processing Kansas, Brown (873/3095)
# Processing Kansas, Butler (874/3095)
# Processing Kansas, Chase (875/3095)
# Processing Kansas, Chautauqua (876/3095)
# Processing Kansas, Cherokee (877/3095)
# Processing Kansas, Cheyenne (878/3095)
# Processing Kansas, Clay (879/3095)
# Processing Kansas, Cloud (880/3095)
# Processing Kansas, Coffey (881/3095)
# Processing Kansas, Cowley (882/3095)
# Processing Kansas, Crawford (883/3095)
# Processing Kansas, Decatur (884/3095)
# Processing Kansas, Dickinson (885/3095)
# Processing Kansas, Doniphan (886/3095)
# Processing Kansas, Douglas (887/3095)
# Processing Kansas, Edwards (888/3095)
# Processing Kansas, Elk (889/3095)
# Processing Kansas, Ellis (890/3095)
# Processing Kansas, Ellsworth (891/3095)
# Processing Kansas, Finney (892/3095)
# Processing Kansas, Franklin (893/3095)
# Processing Kansas, Geary (894/3095)
# Processing Kansas, Gove (895/3095)
# Processing Kansas, Graham (896/3095)
# Processing Kansas, Grant (897/3095)
# Processing Kansas, Gray (898/3095)
# Processing Kansas, Greeley (899/3095)
# Processing Kansas, Greenwood (900/3095)
# Processing Kansas, Hamilton (901/3095)
# Processing Kansas, Harper (902/3095)
# Processing Kansas, Harvey (903/3095)
# Processing Kansas, Haskell (904/3095)
# Processing Kansas, Hodgeman (905/3095)
# Processing Kansas, Jackson (906/3095)
# Processing Kansas, Jefferson (907/3095)
# Processing Kansas, Jewell (908/3095)
# Processing Kansas, Johnson (909/3095)
# Processing Kansas, Kearny (910/3095)
# Processing Kansas, Kingman (911/3095)
# Processing Kansas, Labette (912/3095)
# Processing Kansas, Lane (913/3095)
# Processing Kansas, Leavenworth (914/3095)
# Processing Kansas, Lincoln (915/3095)
# Processing Kansas, Linn (916/3095)
# Processing Kansas, Logan (917/3095)
# Processing Kansas, Lyon (918/3095)
# Processing Kansas, Marion (919/3095)
# Processing Kansas, Marshall (920/3095)
# Processing Kansas, McPherson (921/3095)
# Processing Kansas, Miami (922/3095)
# Processing Kansas, Mitchell (923/3095)
# Processing Kansas, Montgomery (924/3095)
# Processing Kansas, Morris (925/3095)
# Processing Kansas, Morton (926/3095)
# Processing Kansas, Nemaha (927/3095)
# Processing Kansas, Neosho (928/3095)
# Processing Kansas, Ness (929/3095)
# Processing Kansas, Norton (930/3095)
# Processing Kansas, Osage (931/3095)
# Processing Kansas, Osborne (932/3095)
# Processing Kansas, Ottawa (933/3095)
# Processing Kansas, Pawnee (934/3095)
# Processing Kansas, Phillips (935/3095)
# Processing Kansas, Pottawatomie (936/3095)
# Processing Kansas, Pratt (937/3095)
# Processing Kansas, Rawlins (938/3095)
# Processing Kansas, Reno (939/3095)
# Processing Kansas, Republic (940/3095)
# Processing Kansas, Rice (941/3095)
# Processing Kansas, Riley (942/3095)
# Processing Kansas, Rooks (943/3095)
# Processing Kansas, Rush (944/3095)
# Processing Kansas, Russell (945/3095)
# Processing Kansas, Saline (946/3095)
# Processing Kansas, Scott (947/3095)
# Processing Kansas, Sedgwick (948/3095)
# Processing Kansas, Seward (949/3095)
# Processing Kansas, Shawnee (950/3095)
# Processing Kansas, Sheridan (951/3095)
# Processing Kansas, Sherman (952/3095)
# Processing Kansas, Smith (953/3095)
# Processing Kansas, Stafford (954/3095)
# Processing Kansas, Sumner (955/3095)
# Processing Kansas, Thomas (956/3095)
# Processing Kansas, Trego (957/3095)
# Processing Kansas, Wabaunsee (958/3095)
# Processing Kansas, Wallace (959/3095)
# Processing Kansas, Washington (960/3095)
# Processing Kansas, Wichita (961/3095)
# Processing Kansas, Wilson (962/3095)
# Processing Kansas, Woodson (963/3095)
# Processing Kansas, Wyandotte (964/3095)
# Processing Kentucky, Adair (965/3095)
# Processing Kentucky, Allen (966/3095)
# Processing Kentucky, Anderson (967/3095)
# Processing Kentucky, Ballard (968/3095)
# Processing Kentucky, Barren (969/3095)
# Processing Kentucky, Bath (970/3095)
# Processing Kentucky, Bell (971/3095)
# Processing Kentucky, Boone (972/3095)
# Processing Kentucky, Bourbon (973/3095)
# Processing Kentucky, Boyd (974/3095)
# Processing Kentucky, Boyle (975/3095)
# Processing Kentucky, Bracken (976/3095)
# Processing Kentucky, Breathitt (977/3095)
# Processing Kentucky, Breckinridge (978/3095)
# Processing Kentucky, Bullitt (979/3095)
# Processing Kentucky, Butler (980/3095)
# Processing Kentucky, Caldwell (981/3095)
# Processing Kentucky, Calloway (982/3095)
# Processing Kentucky, Campbell (983/3095)
# Processing Kentucky, Carlisle (984/3095)
# Processing Kentucky, Carroll (985/3095)
# Processing Kentucky, Carter (986/3095)
# Processing Kentucky, Casey (987/3095)
# Processing Kentucky, Christian (988/3095)
# Processing Kentucky, Clark (989/3095)
# Processing Kentucky, Clay (990/3095)
# Processing Kentucky, Clinton (991/3095)
# Processing Kentucky, Crittenden (992/3095)
# Processing Kentucky, Cumberland (993/3095)
# Processing Kentucky, Daviess (994/3095)
# Processing Kentucky, Edmonson (995/3095)
# Processing Kentucky, Elliott (996/3095)
# Processing Kentucky, Estill (997/3095)
# Processing Kentucky, Fayette (998/3095)
# Processing Kentucky, Fleming (999/3095)
# Processing Kentucky, Floyd (1000/3095)
# Processing Kentucky, Franklin (1001/3095)
# Processing Kentucky, Fulton (1002/3095)
# Processing Kentucky, Gallatin (1003/3095)
# Processing Kentucky, Garrard (1004/3095)
# Processing Kentucky, Grant (1005/3095)
# Processing Kentucky, Graves (1006/3095)
# Processing Kentucky, Grayson (1007/3095)
# Processing Kentucky, Green (1008/3095)
# Processing Kentucky, Greenup (1009/3095)
# Processing Kentucky, Hancock (1010/3095)
# Processing Kentucky, Hardin (1011/3095)
# Processing Kentucky, Harlan (1012/3095)
# Processing Kentucky, Harrison (1013/3095)
# Processing Kentucky, Hart (1014/3095)
# Processing Kentucky, Henderson (1015/3095)
# Processing Kentucky, Henry (1016/3095)
# Processing Kentucky, Hickman (1017/3095)
# Processing Kentucky, Hopkins (1018/3095)
# Processing Kentucky, Jackson (1019/3095)
# Processing Kentucky, Jefferson (1020/3095)
# Processing Kentucky, Jessamine (1021/3095)
# Processing Kentucky, Johnson (1022/3095)
# Processing Kentucky, Kenton (1023/3095)
# Processing Kentucky, Knott (1024/3095)
# Processing Kentucky, Knox (1025/3095)
# Processing Kentucky, Larue (1026/3095)
# Processing Kentucky, Laurel (1027/3095)
# Processing Kentucky, Lawrence (1028/3095)
# Processing Kentucky, Lee (1029/3095)
# Processing Kentucky, Leslie (1030/3095)
# Processing Kentucky, Letcher (1031/3095)
# Processing Kentucky, Lewis (1032/3095)
# Processing Kentucky, Lincoln (1033/3095)
# Processing Kentucky, Livingston (1034/3095)
# Processing Kentucky, Logan (1035/3095)
# Processing Kentucky, Lyon (1036/3095)
# Processing Kentucky, Madison (1037/3095)
# Processing Kentucky, Magoffin (1038/3095)
# Processing Kentucky, Marion (1039/3095)
# Processing Kentucky, Marshall (1040/3095)
# Processing Kentucky, Martin (1041/3095)
# Processing Kentucky, Mason (1042/3095)
# Processing Kentucky, McCracken (1043/3095)
# Processing Kentucky, McCreary (1044/3095)
# Processing Kentucky, McLean (1045/3095)
# Processing Kentucky, Meade (1046/3095)
# Processing Kentucky, Menifee (1047/3095)
# Processing Kentucky, Mercer (1048/3095)
# Processing Kentucky, Metcalfe (1049/3095)
# Processing Kentucky, Monroe (1050/3095)
# Processing Kentucky, Montgomery (1051/3095)
# Processing Kentucky, Morgan (1052/3095)
# Processing Kentucky, Muhlenberg (1053/3095)
# Processing Kentucky, Nelson (1054/3095)
# Processing Kentucky, Nicholas (1055/3095)
# Processing Kentucky, Ohio (1056/3095)
# Processing Kentucky, Oldham (1057/3095)
# Processing Kentucky, Owen (1058/3095)
# Processing Kentucky, Owsley (1059/3095)
# Processing Kentucky, Pendleton (1060/3095)
# Processing Kentucky, Perry (1061/3095)
# Processing Kentucky, Pike (1062/3095)
# Processing Kentucky, Powell (1063/3095)
# Processing Kentucky, Pulaski (1064/3095)
# Processing Kentucky, Robertson (1065/3095)
# Processing Kentucky, Rockcastle (1066/3095)
# Processing Kentucky, Rowan (1067/3095)
# Processing Kentucky, Russell (1068/3095)
# Processing Kentucky, Scott (1069/3095)
# Processing Kentucky, Shelby (1070/3095)
# Processing Kentucky, Simpson (1071/3095)
# Processing Kentucky, Spencer (1072/3095)
# Processing Kentucky, Taylor (1073/3095)
# Processing Kentucky, Todd (1074/3095)
# Processing Kentucky, Trigg (1075/3095)
# Processing Kentucky, Trimble (1076/3095)
# Processing Kentucky, Union (1077/3095)
# Processing Kentucky, Warren (1078/3095)
# Processing Kentucky, Washington (1079/3095)
# Processing Kentucky, Wayne (1080/3095)
# Processing Kentucky, Webster (1081/3095)
# Processing Kentucky, Whitley (1082/3095)
# Processing Kentucky, Wolfe (1083/3095)
# Processing Kentucky, Woodford (1084/3095)
# Processing Louisiana, Acadia (1085/3095)
# Processing Louisiana, Allen (1086/3095)
# Processing Louisiana, Ascension (1087/3095)
# Processing Louisiana, Assumption (1088/3095)
# Processing Louisiana, Avoyelles (1089/3095)
# Processing Louisiana, Beauregard (1090/3095)
# Processing Louisiana, Bienville (1091/3095)
# Processing Louisiana, Bossier (1092/3095)
# Processing Louisiana, Caddo (1093/3095)
# Processing Louisiana, Calcasieu (1094/3095)
# Processing Louisiana, Caldwell (1095/3095)
# Processing Louisiana, Cameron (1096/3095)
# Processing Louisiana, Catahoula (1097/3095)
# Processing Louisiana, Claiborne (1098/3095)
# Processing Louisiana, Concordia (1099/3095)
# Processing Louisiana, De Soto (1100/3095)
# Processing Louisiana, East Baton Rouge (1101/3095)
# Processing Louisiana, East Carroll (1102/3095)
# Processing Louisiana, East Feliciana (1103/3095)
# Processing Louisiana, Evangeline (1104/3095)
# Processing Louisiana, Franklin (1105/3095)
# Processing Louisiana, Grant (1106/3095)
# Processing Louisiana, Iberia (1107/3095)
# Processing Louisiana, Iberville (1108/3095)
# Processing Louisiana, Jackson (1109/3095)
# Processing Louisiana, Jefferson (1110/3095)
# Processing Louisiana, Jefferson Davis (1111/3095)
# Processing Louisiana, LaSalle (1112/3095)
# Processing Louisiana, Lafayette (1113/3095)
# Processing Louisiana, Lafourche (1114/3095)
# Processing Louisiana, Lincoln (1115/3095)
# Processing Louisiana, Livingston (1116/3095)
# Processing Louisiana, Madison (1117/3095)
# Processing Louisiana, Morehouse (1118/3095)
# Processing Louisiana, Natchitoches (1119/3095)
# Processing Louisiana, Orleans (1120/3095)
# Processing Louisiana, Ouachita (1121/3095)
# Processing Louisiana, Plaquemines (1122/3095)
# Processing Louisiana, Pointe Coupee (1123/3095)
# Processing Louisiana, Rapides (1124/3095)
# Processing Louisiana, Red River (1125/3095)
# Processing Louisiana, Richland (1126/3095)
# Processing Louisiana, Sabine (1127/3095)
# Processing Louisiana, St. Bernard (1128/3095)
# Processing Louisiana, St. Charles (1129/3095)
# Processing Louisiana, St. Helena (1130/3095)
# Processing Louisiana, St. James (1131/3095)
# Processing Louisiana, St. John the Baptist (1132/3095)
# Processing Louisiana, St. Landry (1133/3095)
# Processing Louisiana, St. Martin (1134/3095)
# Processing Louisiana, St. Mary (1135/3095)
# Processing Louisiana, St. Tammany (1136/3095)
# Processing Louisiana, Tangipahoa (1137/3095)
# Processing Louisiana, Tensas (1138/3095)
# Processing Louisiana, Terrebonne (1139/3095)
# Processing Louisiana, Union (1140/3095)
# Processing Louisiana, Vermilion (1141/3095)
# Processing Louisiana, Vernon (1142/3095)
# Processing Louisiana, Washington (1143/3095)
# Processing Louisiana, Webster (1144/3095)
# Processing Louisiana, West Baton Rouge (1145/3095)
# Processing Louisiana, West Carroll (1146/3095)
# Processing Louisiana, West Feliciana (1147/3095)
# Processing Louisiana, Winn (1148/3095)
# Processing Maine, Androscoggin (1149/3095)
# Processing Maine, Aroostook (1150/3095)
# Processing Maine, Cumberland (1151/3095)
# Processing Maine, Franklin (1152/3095)
# Processing Maine, Hancock (1153/3095)
# Processing Maine, Kennebec (1154/3095)
# Processing Maine, Knox (1155/3095)
# Processing Maine, Lincoln (1156/3095)
# Processing Maine, Oxford (1157/3095)
# Processing Maine, Penobscot (1158/3095)
# Processing Maine, Piscataquis (1159/3095)
# Processing Maine, Sagadahoc (1160/3095)
# Processing Maine, Somerset (1161/3095)
# Processing Maine, Waldo (1162/3095)
# Processing Maine, Washington (1163/3095)
# Processing Maine, York (1164/3095)
# Processing Maryland, Allegany (1165/3095)
# Processing Maryland, Anne Arundel (1166/3095)
# Processing Maryland, Baltimore (1167/3095)
# Processing Maryland, Calvert (1168/3095)
# Processing Maryland, Caroline (1169/3095)
# Processing Maryland, Carroll (1170/3095)
# Processing Maryland, Cecil (1171/3095)
# Processing Maryland, Charles (1172/3095)
# Processing Maryland, Dorchester (1173/3095)
# Processing Maryland, Frederick (1174/3095)
# Processing Maryland, Garrett (1175/3095)
# Processing Maryland, Harford (1176/3095)
# Processing Maryland, Howard (1177/3095)
# Processing Maryland, Kent (1178/3095)
# Processing Maryland, Montgomery (1179/3095)
# Processing Maryland, Prince George's (1180/3095)
# Processing Maryland, Queen Anne's (1181/3095)
# Processing Maryland, Somerset (1182/3095)
# Processing Maryland, St. Mary's (1183/3095)
# Processing Maryland, Talbot (1184/3095)
# Processing Maryland, Washington (1185/3095)
# Processing Maryland, Wicomico (1186/3095)
# Processing Maryland, Worcester (1187/3095)
# Processing Massachusetts, Barnstable (1188/3095)
# Processing Massachusetts, Berkshire (1189/3095)
# Processing Massachusetts, Bristol (1190/3095)
# Processing Massachusetts, Dukes (1191/3095)
# Processing Massachusetts, Essex (1192/3095)
# Processing Massachusetts, Franklin (1193/3095)
# Processing Massachusetts, Hampden (1194/3095)
# Processing Massachusetts, Hampshire (1195/3095)
# Processing Massachusetts, Middlesex (1196/3095)
# Processing Massachusetts, Nantucket (1197/3095)
# Processing Massachusetts, Norfolk (1198/3095)
# Processing Massachusetts, Plymouth (1199/3095)
# Processing Massachusetts, Suffolk (1200/3095)
# Processing Massachusetts, Worcester (1201/3095)
# Processing Michigan, Alcona (1202/3095)
# Processing Michigan, Alger (1203/3095)
# Processing Michigan, Allegan (1204/3095)
# Processing Michigan, Alpena (1205/3095)
# Processing Michigan, Antrim (1206/3095)
# Processing Michigan, Arenac (1207/3095)
# Processing Michigan, Baraga (1208/3095)
# Processing Michigan, Barry (1209/3095)
# Processing Michigan, Bay (1210/3095)
# Processing Michigan, Benzie (1211/3095)
# Processing Michigan, Berrien (1212/3095)
# Processing Michigan, Branch (1213/3095)
# Processing Michigan, Calhoun (1214/3095)
# Processing Michigan, Cass (1215/3095)
# Processing Michigan, Charlevoix (1216/3095)
# Processing Michigan, Cheboygan (1217/3095)
# Processing Michigan, Chippewa (1218/3095)
# Processing Michigan, Clare (1219/3095)
# Processing Michigan, Clinton (1220/3095)
# ...
# Processing Texas, Wilson (2719/3095)
# Processing Texas, Winkler (2720/3095)
# Processing Texas, Wise (2721/3095)
# Processing Texas, Wood (2722/3095)
# Processing Texas, Yoakum (2723/3095)
# Processing Texas, Young (2724/3095)
# Processing Texas, Zapata (2725/3095)
# Processing Texas, Zavala (2726/3095)
# Processing US Virgin Islands, St. Croix (2727/3095)
# Processing US Virgin Islands, St. John (2728/3095)
# Processing US Virgin Islands, St. Thomas (2729/3095)
# Processing United States Virgin Islands, St. Croix (2730/3095)
# Processing United States Virgin Islands, St. John (2731/3095)
# Processing United States Virgin Islands, St. Thomas (2732/3095)
# Processing Utah, Beaver (2733/3095)
# Processing Utah, Box Elder (2734/3095)
# Processing Utah, Cache (2735/3095)
# Processing Utah, Carbon (2736/3095)
# Processing Utah, Daggett (2737/3095)
# Processing Utah, Davis (2738/3095)
# Processing Utah, Duchesne (2739/3095)
# Processing Utah, Emery (2740/3095)
# Processing Utah, Garfield (2741/3095)
# Processing Utah, Grand (2742/3095)
# Processing Utah, Iron (2743/3095)
# Processing Utah, Juab (2744/3095)
# Processing Utah, Kane (2745/3095)
# Processing Utah, Millard (2746/3095)
# Processing Utah, Morgan (2747/3095)
# Processing Utah, Piute (2748/3095)
# Processing Utah, Rich (2749/3095)
# Processing Utah, Salt Lake (2750/3095)
# Processing Utah, San Juan (2751/3095)
# Processing Utah, Sanpete (2752/3095)
# Processing Utah, Sevier (2753/3095)
# Processing Utah, Summit (2754/3095)
# Processing Utah, Tooele (2755/3095)
# Processing Utah, Uintah (2756/3095)
# Processing Utah, Utah (2757/3095)
# Processing Utah, Wasatch (2758/3095)
# Processing Utah, Washington (2759/3095)
# Processing Utah, Wayne (2760/3095)
# Processing Utah, Weber (2761/3095)
# Processing Vermont, Addison (2762/3095)
# Processing Vermont, Bennington (2763/3095)
# Processing Vermont, Caledonia (2764/3095)
# Processing Vermont, Chittenden (2765/3095)
# Processing Vermont, Essex (2766/3095)
# Processing Vermont, Franklin (2767/3095)
# Processing Vermont, Grand Isle (2768/3095)
# Processing Vermont, Lamoille (2769/3095)
# Processing Vermont, Orange (2770/3095)
# Processing Vermont, Orleans (2771/3095)
# Processing Vermont, Rutland (2772/3095)
# Processing Vermont, Washington (2773/3095)
# Processing Vermont, Windham (2774/3095)
# Processing Vermont, Windsor (2775/3095)
# Processing Virginia, Accomack (2776/3095)
# Processing Virginia, Albemarle (2777/3095)
# Processing Virginia, Alexandria (2778/3095)
# Processing Virginia, Alleghany (2779/3095)
# Processing Virginia, Amelia (2780/3095)
# Processing Virginia, Amherst (2781/3095)
# Processing Virginia, Appomattox (2782/3095)
# Processing Virginia, Arlington (2783/3095)
# Processing Virginia, Augusta (2784/3095)
# Processing Virginia, Bath (2785/3095)
# Processing Virginia, Bedford (2786/3095)
# Processing Virginia, Bland (2787/3095)
# Processing Virginia, Botetourt (2788/3095)
# Processing Virginia, Bristol (2789/3095)
# Processing Virginia, Brunswick (2790/3095)
# Processing Virginia, Buchanan (2791/3095)
# Processing Virginia, Buckingham (2792/3095)
# Processing Virginia, Buena Vista (2793/3095)
# Processing Virginia, Campbell (2794/3095)
# Processing Virginia, Caroline (2795/3095)
# Processing Virginia, Carroll (2796/3095)
# Processing Virginia, Charles City (2797/3095)
# Processing Virginia, Charlotte (2798/3095)
# Processing Virginia, Charlottesville (2799/3095)
# Processing Virginia, Chesapeake (2800/3095)
# Processing Virginia, Chesterfield (2801/3095)
# Processing Virginia, Clarke (2802/3095)
# Processing Virginia, Colonial Heights (2803/3095)
# Processing Virginia, Covington (2804/3095)
# Processing Virginia, Craig (2805/3095)
# Processing Virginia, Culpeper (2806/3095)
# Processing Virginia, Cumberland (2807/3095)
# Processing Virginia, Danville (2808/3095)
# Processing Virginia, Dickenson (2809/3095)
# Processing Virginia, Dinwiddie (2810/3095)
# Processing Virginia, Emporia (2811/3095)
# Processing Virginia, Essex (2812/3095)
# Processing Virginia, Fairfax (2813/3095)
# Processing Virginia, Fairfax City (2814/3095)
# Processing Virginia, Falls Church (2815/3095)
# Processing Virginia, Fauquier (2816/3095)
# Processing Virginia, Floyd (2817/3095)
# Processing Virginia, Fluvanna (2818/3095)
# Processing Virginia, Franklin (2819/3095)
# Processing Virginia, Franklin City (2820/3095)
# Processing Virginia, Frederick (2821/3095)
# Processing Virginia, Fredericksburg (2822/3095)
# Processing Virginia, Galax (2823/3095)
# Processing Virginia, Giles (2824/3095)
# Processing Virginia, Gloucester (2825/3095)
# Processing Virginia, Goochland (2826/3095)
# Processing Virginia, Grayson (2827/3095)
# Processing Virginia, Greene (2828/3095)
# Processing Virginia, Greensville (2829/3095)
# Processing Virginia, Halifax (2830/3095)
# Processing Virginia, Hampton (2831/3095)
# Processing Virginia, Hanover (2832/3095)
# Processing Virginia, Harrisonburg (2833/3095)
# Processing Virginia, Henrico (2834/3095)
# Processing Virginia, Henry (2835/3095)
# Processing Virginia, Highland (2836/3095)
# Processing Virginia, Hopewell (2837/3095)
# Processing Virginia, Isle of Wight (2838/3095)
# Processing Virginia, James City (2839/3095)
# Processing Virginia, King George (2840/3095)
# Processing Virginia, King William (2841/3095)
# Processing Virginia, King and Queen (2842/3095)
# Processing Virginia, Lancaster (2843/3095)
# Processing Virginia, Lee (2844/3095)
# Processing Virginia, Lexington (2845/3095)
# Processing Virginia, Loudoun (2846/3095)
# Processing Virginia, Louisa (2847/3095)
# Processing Virginia, Lunenburg (2848/3095)
# Processing Virginia, Lynchburg (2849/3095)
# Processing Virginia, Madison (2850/3095)
# Processing Virginia, Manassas (2851/3095)
# Processing Virginia, Manassas Park (2852/3095)
# Processing Virginia, Martinsville (2853/3095)
# Processing Virginia, Mathews (2854/3095)
# Processing Virginia, Mecklenburg (2855/3095)
# Processing Virginia, Middlesex (2856/3095)
# Processing Virginia, Montgomery (2857/3095)
# Processing Virginia, Nelson (2858/3095)
# Processing Virginia, New Kent (2859/3095)
# Processing Virginia, Newport News (2860/3095)
# Processing Virginia, Norfolk (2861/3095)
# Processing Virginia, Northampton (2862/3095)
# Processing Virginia, Northumberland (2863/3095)
# Processing Virginia, Norton (2864/3095)
# Processing Virginia, Nottoway (2865/3095)
# Processing Virginia, Orange (2866/3095)
# Processing Virginia, Page (2867/3095)
# Processing Virginia, Patrick (2868/3095)
# Processing Virginia, Petersburg (2869/3095)
# Processing Virginia, Pittsylvania (2870/3095)
# Processing Virginia, Poquoson (2871/3095)
# Processing Virginia, Portsmouth (2872/3095)
# Processing Virginia, Powhatan (2873/3095)
# Processing Virginia, Prince Edward (2874/3095)
# Processing Virginia, Prince George (2875/3095)
# Processing Virginia, Prince William (2876/3095)
# Processing Virginia, Pulaski (2877/3095)
# Processing Virginia, Radford (2878/3095)
# Processing Virginia, Rappahannock (2879/3095)
# Processing Virginia, Richmond (2880/3095)
# Processing Virginia, Roanoke (2881/3095)
# Processing Virginia, Rockbridge (2882/3095)
# Processing Virginia, Rockingham (2883/3095)
# Processing Virginia, Russell (2884/3095)
# Processing Virginia, Salem (2885/3095)
# Processing Virginia, Scott (2886/3095)
# Processing Virginia, Shenandoah (2887/3095)
# Processing Virginia, Smyth (2888/3095)
# Processing Virginia, Southampton (2889/3095)
# Processing Virginia, Spotsylvania (2890/3095)
# Processing Virginia, Stafford (2891/3095)
# Processing Virginia, Staunton (2892/3095)
# Processing Virginia, Suffolk (2893/3095)
# Processing Virginia, Surry (2894/3095)
# Processing Virginia, Sussex (2895/3095)
# Processing Virginia, Tazewell (2896/3095)
# Processing Virginia, Virginia Beach (2897/3095)
# Processing Virginia, Warren (2898/3095)
# Processing Virginia, Washington (2899/3095)
# Processing Virginia, Waynesboro (2900/3095)
# Processing Virginia, Westmoreland (2901/3095)
# Processing Virginia, Williamsburg (2902/3095)
# Processing Virginia, Winchester (2903/3095)
# Processing Virginia, Wise (2904/3095)
# Processing Virginia, Wythe (2905/3095)
# Processing Virginia, York (2906/3095)
# Processing Washington, Adams (2907/3095)
# Processing Washington, Asotin (2908/3095)
# Processing Washington, Benton (2909/3095)
# Processing Washington, Chelan (2910/3095)
# Processing Washington, Clallam (2911/3095)
# Processing Washington, Clark (2912/3095)
# Processing Washington, Columbia (2913/3095)
# Processing Washington, Cowlitz (2914/3095)
# Processing Washington, Douglas (2915/3095)
# Processing Washington, Ferry (2916/3095)
# Processing Washington, Franklin (2917/3095)
# Processing Washington, Garfield (2918/3095)
# Processing Washington, Grant (2919/3095)
# Processing Washington, Grays Harbor (2920/3095)
# Processing Washington, Island (2921/3095)
# Processing Washington, Jefferson (2922/3095)
# Processing Washington, King (2923/3095)
# Processing Washington, Kitsap (2924/3095)
# Processing Washington, Kittitas (2925/3095)
# Processing Washington, Klickitat (2926/3095)
# Processing Washington, Lewis (2927/3095)
# Processing Washington, Lincoln (2928/3095)
# Processing Washington, Mason (2929/3095)
# Processing Washington, Okanogan (2930/3095)
# Processing Washington, Pacific (2931/3095)
# Processing Washington, Pend Oreille (2932/3095)
# Processing Washington, Pierce (2933/3095)
# Processing Washington, San Juan (2934/3095)
# Processing Washington, Skagit (2935/3095)
# Processing Washington, Skamania (2936/3095)
# Processing Washington, Snohomish (2937/3095)
# Processing Washington, Spokane (2938/3095)
# Processing Washington, Stevens (2939/3095)
# Processing Washington, Thurston (2940/3095)
# Processing Washington, Wahkiakum (2941/3095)
# Processing Washington, Walla Walla (2942/3095)
# Processing Washington, Whatcom (2943/3095)
# Processing Washington, Whitman (2944/3095)
# Processing Washington, Yakima (2945/3095)
# Processing West Virginia, Barbour (2946/3095)
# Processing West Virginia, Berkeley (2947/3095)
# Processing West Virginia, Boone (2948/3095)
# Processing West Virginia, Braxton (2949/3095)
# Processing West Virginia, Brooke (2950/3095)
# Processing West Virginia, Cabell (2951/3095)
# Processing West Virginia, Calhoun (2952/3095)
# Processing West Virginia, Clay (2953/3095)
# Processing West Virginia, Doddridge (2954/3095)
# Processing West Virginia, Fayette (2955/3095)
# Processing West Virginia, Gilmer (2956/3095)
# Processing West Virginia, Grant (2957/3095)
# Processing West Virginia, Greenbrier (2958/3095)
# Processing West Virginia, Hampshire (2959/3095)
# Processing West Virginia, Hancock (2960/3095)
# Processing West Virginia, Hardy (2961/3095)
# Processing West Virginia, Harrison (2962/3095)
# Processing West Virginia, Jackson (2963/3095)
# Processing West Virginia, Jefferson (2964/3095)
# Processing West Virginia, Kanawha (2965/3095)
# Processing West Virginia, Lewis (2966/3095)
# Processing West Virginia, Lincoln (2967/3095)
# Processing West Virginia, Logan (2968/3095)
# Processing West Virginia, Marion (2969/3095)
# Processing West Virginia, Marshall (2970/3095)
# Processing West Virginia, Mason (2971/3095)
# Processing West Virginia, McDowell (2972/3095)
# Processing West Virginia, Mercer (2973/3095)
# Processing West Virginia, Mineral (2974/3095)
# Processing West Virginia, Mingo (2975/3095)
# Processing West Virginia, Monongalia (2976/3095)
# Processing West Virginia, Monroe (2977/3095)
# Processing West Virginia, Morgan (2978/3095)
# Processing West Virginia, Nicholas (2979/3095)
# Processing West Virginia, Ohio (2980/3095)
# Processing West Virginia, Pendleton (2981/3095)
# Processing West Virginia, Pleasants (2982/3095)
# Processing West Virginia, Pocahontas (2983/3095)
# Processing West Virginia, Preston (2984/3095)
# Processing West Virginia, Putnam (2985/3095)
# Processing West Virginia, Raleigh (2986/3095)
# Processing West Virginia, Randolph (2987/3095)
# Processing West Virginia, Ritchie (2988/3095)
# Processing West Virginia, Roane (2989/3095)
# Processing West Virginia, Summers (2990/3095)
# Processing West Virginia, Taylor (2991/3095)
# Processing West Virginia, Tucker (2992/3095)
# Processing West Virginia, Tyler (2993/3095)
# Processing West Virginia, Upshur (2994/3095)
# Processing West Virginia, Wayne (2995/3095)
# Processing West Virginia, Webster (2996/3095)
# Processing West Virginia, Wetzel (2997/3095)
# Processing West Virginia, Wirt (2998/3095)
# Processing West Virginia, Wood (2999/3095)
# Processing West Virginia, Wyoming (3000/3095)
# Processing Wisconsin, Adams (3001/3095)
# Processing Wisconsin, Ashland (3002/3095)
# Processing Wisconsin, Barron (3003/3095)
# Processing Wisconsin, Bayfield (3004/3095)
# Processing Wisconsin, Brown (3005/3095)
# Processing Wisconsin, Buffalo (3006/3095)
# Processing Wisconsin, Burnett (3007/3095)
# Processing Wisconsin, Calumet (3008/3095)
# Processing Wisconsin, Chippewa (3009/3095)
# Processing Wisconsin, Clark (3010/3095)
# Processing Wisconsin, Columbia (3011/3095)
# Processing Wisconsin, Crawford (3012/3095)
# Processing Wisconsin, Dane (3013/3095)
# Processing Wisconsin, Dodge (3014/3095)
# Processing Wisconsin, Door (3015/3095)
# Processing Wisconsin, Douglas (3016/3095)
# Processing Wisconsin, Dunn (3017/3095)
# Processing Wisconsin, Eau Claire (3018/3095)
# Processing Wisconsin, Florence (3019/3095)
# Processing Wisconsin, Fond du Lac (3020/3095)
# Processing Wisconsin, Forest (3021/3095)
# Processing Wisconsin, Grant (3022/3095)
# Processing Wisconsin, Green (3023/3095)
# Processing Wisconsin, Green Lake (3024/3095)
# Processing Wisconsin, Iowa (3025/3095)
# Processing Wisconsin, Iron (3026/3095)
# Processing Wisconsin, Jackson (3027/3095)
# Processing Wisconsin, Jefferson (3028/3095)
# Processing Wisconsin, Juneau (3029/3095)
# Processing Wisconsin, Kenosha (3030/3095)
# Processing Wisconsin, Kewaunee (3031/3095)
# Processing Wisconsin, La Crosse (3032/3095)
# Processing Wisconsin, Lafayette (3033/3095)
# Processing Wisconsin, Langlade (3034/3095)
# Processing Wisconsin, Lincoln (3035/3095)
# Processing Wisconsin, Manitowoc (3036/3095)
# Processing Wisconsin, Marathon (3037/3095)
# Processing Wisconsin, Marinette (3038/3095)
# Processing Wisconsin, Marquette (3039/3095)
# Processing Wisconsin, Menominee (3040/3095)
# Processing Wisconsin, Milwaukee (3041/3095)
# Processing Wisconsin, Monroe (3042/3095)
# Processing Wisconsin, Oconto (3043/3095)
# Processing Wisconsin, Oneida (3044/3095)
# Processing Wisconsin, Outagamie (3045/3095)
# Processing Wisconsin, Ozaukee (3046/3095)
# Processing Wisconsin, Pepin (3047/3095)
# Processing Wisconsin, Pierce (3048/3095)
# Processing Wisconsin, Polk (3049/3095)
# Processing Wisconsin, Portage (3050/3095)
# Processing Wisconsin, Price (3051/3095)
# Processing Wisconsin, Racine (3052/3095)
# Processing Wisconsin, Richland (3053/3095)
# Processing Wisconsin, Rock (3054/3095)
# Processing Wisconsin, Rusk (3055/3095)
# Processing Wisconsin, Sauk (3056/3095)
# Processing Wisconsin, Sawyer (3057/3095)
# Processing Wisconsin, Shawano (3058/3095)
# Processing Wisconsin, Sheboygan (3059/3095)
# Processing Wisconsin, St. Croix (3060/3095)
# Processing Wisconsin, Taylor (3061/3095)
# Processing Wisconsin, Trempealeau (3062/3095)
# Processing Wisconsin, Vernon (3063/3095)
# Processing Wisconsin, Vilas (3064/3095)
# Processing Wisconsin, Walworth (3065/3095)
# Processing Wisconsin, Washburn (3066/3095)
# Processing Wisconsin, Washington (3067/3095)
# Processing Wisconsin, Waukesha (3068/3095)
# Processing Wisconsin, Waupaca (3069/3095)
# Processing Wisconsin, Waushara (3070/3095)
# Processing Wisconsin, Winnebago (3071/3095)
# Processing Wisconsin, Wood (3072/3095)
# Processing Wyoming, Albany (3073/3095)
# Processing Wyoming, Big Horn (3074/3095)
# Processing Wyoming, Campbell (3075/3095)
# Processing Wyoming, Carbon (3076/3095)
# Processing Wyoming, Converse (3077/3095)
# Processing Wyoming, Crook (3078/3095)
# Processing Wyoming, Fremont (3079/3095)
# Processing Wyoming, Goshen (3080/3095)
# Processing Wyoming, Hot Springs (3081/3095)
# Processing Wyoming, Johnson (3082/3095)
# Processing Wyoming, Laramie (3083/3095)
# Processing Wyoming, Lincoln (3084/3095)
# Processing Wyoming, Natrona (3085/3095)
# Processing Wyoming, Niobrara (3086/3095)
# Processing Wyoming, Park (3087/3095)
# Processing Wyoming, Platte (3088/3095)
# Processing Wyoming, Sheridan (3089/3095)
# Processing Wyoming, Sublette (3090/3095)
# Processing Wyoming, Sweetwater (3091/3095)
# Processing Wyoming, Teton (3092/3095)
# Processing Wyoming, Uinta (3093/3095)
# Processing Wyoming, Washakie (3094/3095)
# Processing Wyoming, Weston (3095/3095)

# %%
print(outage_summary.sort_values('duration', ascending=False).head(10).to_markdown())
# Out:
# |          |    group | state         | county       | start_time          | end_time            |   min_customers |   max_customers |   avg_customers | duration          |
# |---------:|---------:|:--------------|:-------------|:--------------------|:--------------------|----------------:|----------------:|----------------:|:------------------|
# |  5447407 |  5447407 | Massachusetts | Hampden      | 2022-01-01 00:00:00 | 2022-08-23 18:30:00 |               1 |           23142 |       215.161   | 234 days 18:30:00 |
# |   779627 |   779627 | California    | Los Angeles  | 2022-05-31 13:30:00 | 2022-10-18 23:00:00 |               1 |           93099 |      2027.89    | 140 days 09:30:00 |
# |   779573 |   779573 | California    | Los Angeles  | 2020-07-12 11:15:00 | 2020-10-20 10:45:00 |               1 |           65931 |      2349.69    | 99 days 23:30:00  |
# |  7265819 |  7265819 | New Jersey    | Morris       | 2022-05-15 11:45:00 | 2022-08-19 17:15:00 |               4 |           27353 |       132.137   | 96 days 05:30:00  |
# |   394970 |   394970 | Arkansas      | Arkansas     | 2022-05-07 05:15:00 | 2022-08-02 17:45:00 |               1 |            1787 |        24.6571  | 87 days 12:30:00  |
# |   779619 |   779619 | California    | Los Angeles  | 2022-01-01 00:00:00 | 2022-03-25 11:00:00 |               1 |           35499 |      1775.54    | 83 days 11:00:00  |
# | 10951618 | 10951618 | Texas         | Harris       | 2019-07-27 19:00:00 | 2019-10-19 05:45:00 |               1 |           36534 |      1621.72    | 83 days 10:45:00  |
# |   779629 |   779629 | California    | Los Angeles  | 2022-10-19 00:45:00 | 2023-01-08 15:00:00 |               1 |           25236 |      1914.1     | 81 days 14:15:00  |
# |  4791992 |  4791992 | Louisiana     | St. Mary     | 2019-07-27 19:00:00 | 2019-10-08 20:15:00 |               4 |             387 |         9.63202 | 73 days 01:15:00  |
# |  9727519 |  9727519 | Pennsylvania  | Philadelphia | 2022-04-20 00:00:00 | 2022-06-27 07:45:00 |               4 |            4988 |       105.379   | 68 days 07:45:00  |

# %%
display(outage_summary.sort_values('avg_customers', ascending=False).head(10))
# Out:
#            group    state      county          start_time            end_time  \
# 1570579  1570579  Florida  Miami-Dade 2017-09-11 13:45:00 2017-09-11 14:15:00
# 1570578  1570578  Florida  Miami-Dade 2017-09-11 01:30:00 2017-09-11 13:15:00
# 1570580  1570580  Florida  Miami-Dade 2017-09-11 14:45:00 2017-09-11 18:30:00
# 1276503  1276503  Florida     Broward 2017-09-11 13:45:00 2017-09-11 14:15:00
# 1627889  1627889  Florida  Palm Beach 2017-09-11 13:45:00 2017-09-11 14:15:00
# 1276502  1276502  Florida     Broward 2017-09-11 01:30:00 2017-09-11 13:15:00
# 1276504  1276504  Florida     Broward 2017-09-11 14:45:00 2017-09-11 18:30:00
# 1627890  1627890  Florida  Palm Beach 2017-09-11 14:45:00 2017-09-11 18:30:00
# 1627888  1627888  Florida  Palm Beach 2017-09-11 01:30:00 2017-09-11 13:15:00
# 1570581  1570581  Florida  Miami-Dade 2017-09-11 19:00:00 2017-09-14 11:45:00
#
#          min_customers  max_customers  avg_customers        duration
# 1570579         808450        1618030   1.078687e+06 0 days 00:30:00
# 1570578         775220        1777800   8.630394e+05 0 days 11:45:00
# 1570580         802430        1616900   8.629662e+05 0 days 03:45:00
# 1276503         636850        1275330   8.502200e+05 0 days 00:30:00
# 1627889         517690        1044000   6.960000e+05 0 days 00:30:00
# 1276502         632320        1398920   6.765910e+05 0 days 11:45:00
# 1276504         629080        1273700   6.741394e+05 0 days 03:45:00
# 1627890         509490        1035380   5.530706e+05 0 days 03:45:00
# 1627888         523140        1098160   5.491340e+05 0 days 11:45:00
# 1570581         314040        1604860   5.466466e+05 2 days 16:45:00

# %%
len(outage_summary[outage_summary['min_customers'] > 100])
# Out:
# 327841

# %%
state = 'Virginia'
county = 'Albemarle'

query = f"""
    SELECT
        state,
        county,
        customers_out,
        run_start_time
    FROM
        eaglei_data
    WHERE
        customers_out IS NOT NULL
        AND customers_out > 0
        AND state = '{state}'
        AND county = '{county}'
    ORDER BY run_start_time
    """

with duckdb.connect(database=db_path) as conn:
    df = conn.execute(query).fetchdf()
    display(df[(df['run_start_time'] >= '2021-12-28') & (df['run_start_time'] <= '2022-01-01')])
# Out:
#                state   county  customers_out      run_start_time
# 83085  Massachusetts  Hampden             10 2021-12-28 00:00:00
# 83086  Massachusetts  Hampden             10 2021-12-28 00:15:00
# 83087  Massachusetts  Hampden             10 2021-12-28 00:30:00
# 83088  Massachusetts  Hampden             10 2021-12-28 00:45:00
# 83089  Massachusetts  Hampden             10 2021-12-28 01:00:00
# ...              ...      ...            ...                 ...
# 83370  Massachusetts  Hampden             16 2021-12-30 23:15:00
# 83371  Massachusetts  Hampden             16 2021-12-30 23:30:00
# 83372  Massachusetts  Hampden             16 2021-12-30 23:45:00
# 83373  Massachusetts  Hampden             16 2021-12-31 00:00:00
# 83374  Massachusetts  Hampden             16 2022-01-01 00:00:00
#
# [290 rows x 4 columns]
